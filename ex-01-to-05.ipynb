# %% [markdown]
# 1.1.1 Exercise 1: Declare and Print Variables
# Objective: Understand how to declare and print variables in Python.
# Task:
# • Declare variables for an instructor’s name, the number of students in a Python class,
# and the course name.
# • Print them using a formatted string.
# Expected Output Example:
# The instructor is Alex, there are 30 students in the Python class!

# %%
a = str(input("Instructor's name: "))
b = int(input("Number of students in class: "))
c = str(input("Name of the course: "))

if b > 1:
    print("The instructor is",a,", there are",b,"students in the",c,"class!\n")
elif b == 1:
    print("The instructor is",a,", there is",b,"student in the",c,"class!\n")
else: 
    print("Invalid number of students.\n")

# edge cases.
# Out:
# Instructor's name:  Gabriel
# Number of students in class:  1
# Name of the course:  Mathematics and Statistics
# The instructor is Gabriel , there is 1 student in the Mathematics and Statistics class!

# %% [markdown]
# Exercise 2: Swap Two Variables Without a Third Variable
# Objective: Swap two values without using a temporary variable.
# Task:
# • Swap the values of students_morning = 15 and students_evening = 25 without us
# ing an extra variable.
# Expected Output:
# Before Swap: Morning Batch = 15, Evening Batch = 25
# After Swap: Morning Batch = 25, Evening Batch = 15

# %%
students_morning = int(input("Morning Batch = "))
students_evening = int(input("Evening Batch = "))

students_morning, students_evening = students_evening, students_morning

# I really wanted to use a temporary variable. 

print("After Swap: Moning Batch =",students_morning,"Evening Batch =",students_evening,"\n")
# Out:
# Morning Batch =  42
# Evening Batch =  37
# After Swap: Moning Batch = 37 Evening Batch = 42

# %% [markdown]
# Exercise 3: Assign Multiple Variables in One Line
# Objective: Learn how to assign multiple variables in one line.
# Task:
# • Assign values to three variables representing the number of Python, Java, and AI stu
# dents in a single line.
# Expected Output:
# Python = 25, Java = 18, AI = 12

# %%
py, java, ai = 13,21,34

print(f"Python = {py}, Java = {java}, AI = {ai}\n")

# didn't know about the print(f"...{}..."). It will be useful from now on.
# Out:
# Python = 13, Java = 21, AI = 34

# %% [markdown]
# Exercise 4: Check the Type of a Variable
# Objective: Learn how to check variable types using type().
# Task:
# • Declare different types of variables: an integer (age), a float (course rating), and a
# string (course name).
# • Use type() to check their data types.
# Expected Output:
# 21 is of type <class 'int'>
# 4.9 is of type <class 'float'>
# Python Programming is of type <class 'str'>

# %%
age = 23
course_rating = 82.5
course_name = "Linear Algebra"

print(f"{age} is of type {type(age)}\n{course_rating} is of type {type(course_rating)}\n{course_name} is of type {type(course_name)}\n")
# Out:
# 23 is of type <class 'int'>
# 82.5 is of type <class 'float'>
# Linear Algebra is of type <class 'str'>

# %% [markdown]
# Exercise 5: Concatenating Strings
# Objective: Learn how to concatenate (combine) multiple strings in Python.
# Task:
# • Declare three separate string variables: instructor, academy name, and slogan.
# • Concatenate them to form a full sentence.
# • Print the combined string.
# Expected Output:
# The instructor at Lkhibra Academy says: "Learning Python is fun!"

# %%
instructor = "Pedro Olmo"
academy_name = "UFMG"
slogan = "Incipit vita nova"

sum = "The instructor " + instructor + " at " + academy_name + " says: " + "'" + slogan + "'"

print(sum)

# concatenating in C is a hell of a lot more complicated.
# Out:
# The instructor Pedro Olmo at UFMG says: 'Incipit vita nova'
